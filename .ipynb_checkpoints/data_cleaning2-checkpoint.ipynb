# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import xlrd
# import plotly.graph_objs as go
import functools
import re
import plotly.graph_objects as go
pd.set_option('display.max_rows', 150)

# %%
df = pd.read_excel("2003-2016 Seed Potato Cert data v20191204_NO FL lines_Rioux 5AUG2020.xlsx", sheet_name="2003-2016 Seed Potato Cert")

# %%
df.shape
# Out:
# (7502, 147)

# %%
df.head()
# Out:
#    SummerID    CY  CERT_N                    LNAME      SNAME GCODE  \
# 0       227  2007  107150  Bula Potato Farms, Inc.    Bula Po   114
# 1       272  2003  103207  Bula Potato Farms, Inc.    Bula Po   114
# 2       282  2003  103217  Bula Potato Farms, Inc.    Bula Po   114
# 3         3  2009  109003    Guenthner Farms, Inc.  Guen Farm   149
# 4        10  2009  109003    Guenthner Farms, Inc.  Guen Farm   149
#
#                VARIETY                  VAR                   V2  \
# 0  1975-11-15 00:00:00  1975-11-15 00:00:00  1975-11-15 00:00:00
# 1            A-88338-1            A-88338-1            A-88338-1
# 2           A-90586-11           A-90586-11           A-90586-11
# 3            A-91814-5            A-91814-5            A-91814-5
# 4            A-91814-5            A-91814-5            A-91814-5
#
#                   V3AR  ... winter_TBR winter_TOTV  winter_CLASS winter_GEN  \
# 0  1975-11-15 00:00:00  ...        NaN        0.00           NaN        NaN
# 1            A-88338-1  ...        NaN        0.00           NaN        NaN
# 2           A-90586-11  ...        NaN        3.75     Certified        NaN
# 3            A-91814-5  ...        NaN        0.00    Foundation       FY-2
# 4            A-91814-5  ...        NaN        0.00    Foundation       FY-2
#
#   winter_PAYING                      winter_SF_PROG winter_FY winter_DIP  \
# 0           NaN  75-11-15       Summit Labs    2007         1          N
# 1           NaN  A-88338-1      Manhattan      2003         4        NaN
# 2           NaN  A-90586-11     Manhattan      2003         4        NaN
# 3           NaN  A-91814-5      State Farm     2009       NaN          N
# 4           NaN  A-91814-5      State Farm     2009       NaN          N
#
#   winter_AC_REJ winter_CY
# 0           NaN    2007.0
# 1           0.0    2003.0
# 2           0.0    2003.0
# 3           NaN    2009.0
# 4           NaN    2009.0
#
# [5 rows x 147 columns]

# %% [markdown]
# ### Data Validation

# %% [markdown]
# #### Inspection day
#
# Hypothesis: **DASP1** should be smaller than **DASP2**

# %%
# df[["DONE_PLTG","DATE_1ST", "DATE_2ND"]] = df[["DONE_PLTG","DATE_1ST", "DATE_2ND"]].astype('datetime64[ns]')
# df[["DONE_PLTG","DATE_1ST", "DATE_2ND"]]

# %%
df.loc[df["DAPS1"] > df["DAPS2"], df.columns.str.contains("DA")]
# Out:
#        DATE_1ST  DAPS1   DATE_2ND  DAPS2
# 6182  6/30/2005     38  6/16/2005     24

# %%
# df["DATE_1ST"] - df["DONE_PLTG"]

# %% [markdown]
# #### Source Year
#
# Hypothesis: **CY** should be larger than or equal to **S_YR** <br>
#
# -CY: year entered certification program <br>
# -S_YR: source year

# %%
df[(df["CY"] <df["S_YR"]) | (df["CY"] <df["winter_S_YR"])]
# Out:
# Empty DataFrame
# Columns: [SummerID, CY, CERT_N, LNAME, SNAME, GCODE, VARIETY, VAR, V2, V3AR, S_GRW, S_G, S_YR, S_GCODE, S_STATE, ACRES, I_CLASS, I_GEN, START_PLTG, DONE_PLTG, DATE_1ST, INSPECTOR, INS_TITL, DAPS1, PLTCT1, NO_LR_1ST, SR1_LR, NO_MOS_1ST, SR1_MOS, NO_ST_1ST, SR1_ST, SR1_TOTV, NO_MIX_1ST, AC_MIX_1ST, SR1_MIX, DATE_2ND, DAPS2, PLTCT2, SR2_LR, SR2_MOS, SR2_ST, SR2_TOTV, NO_BRR_2ND, SR2_BRR, NO_MIX_2ND, AC_MIX_2ND, SR2_MIX, PPA_MIX, SRF_LR, SRF_MOS, SRF_ST, SRF_MIX, TOTVIR, BLEG_PCT_C, BLEG_PCT_N, RHIZOC, VERT_C, VERT_N, ASTRYELOS, EBLIGHT, EBLIGHT_N, LBLIGHT, SCLEROTIN, WILT_PCT_C, WILT_PCT_N, G_AND_VIG, INS_CONT, WEED_CONT, ISOLATION, STAND, COMMMENTS, AC_PASSD, AC_REJ, S_CLASS, S_GEN, DN_CLASS, PRN_F, BR_F, PSTV_F, LB_F, LAST_MOD, LAST_TIM, STOP, SF_HCNOT1, SF_HCNOT2, SF_HCNOT3, SF_HCNOT4, SF_HCNOT5, SF_HCNOT6, SF_HCNOT7, ADDRESSS, CITY, STATE, ZIP, SF_HCNOT8, SF_HCNOT9, SF_HCNOT10, SF_HCNOT11, WinterID, winter_CERT_N, ...]
# Index: []
#
# [0 rows x 147 columns]

# %% [markdown]
# #### Check one-to-one relationship between source grower and source grower code
#
# Hypothesis: One source grower should only have one source grower code

# %%
# One source code correspond 5 different source grower

grw_count = df[["S_GRW","S_GCODE"]].groupby("S_GCODE").apply(lambda x: x["S_GRW"].nunique())
grw_count[grw_count > 2]
# Out:
# S_GCODE
# 243    5
# dtype: int64

# %%
winter_grw_count = df[["winter_S_GRW","winter_S_GCODE"]].groupby("winter_S_GCODE").apply(lambda x: x["winter_S_GRW"].nunique())
winter_grw_count[winter_grw_count > 2]
# Out:
# winter_S_GCODE
# 243    5
# dtype: int64

# %%
grw_count = df[["S_GRW","S_GCODE"]].groupby("S_GCODE").apply(lambda x: x["S_GRW"].nunique())
grw_count[grw_count > 2]
# Out:
# S_GCODE
# 243    5
# dtype: int64

# %%
# It seems like these 5 source grower are actually one source grower in different format
df[df["S_GCODE"] == 243]["S_GRW"].value_counts()
# Out:
# Felix Zeloski Farms-Eagle River     200
# Eagle River Seed Farm LLC            11
# Zeloski Farms-Eagle River             6
# Zeloski, Felix Farms-Eagle River      2
#  Zeloski Farms-Eagle River            1
# Name: S_GRW, dtype: int64

# %%
df[df["winter_S_GCODE"] == 243]["winter_S_GRW"].value_counts()
# Out:
# Felix Zeloski Farms-Eagle River     196
# Eagle River Seed Farm LLC            11
# Zeloski Farms-Eagle River             6
# Zeloski, Felix Farms-Eagle River      2
#  Zeloski Farms-Eagle River            1
# Name: winter_S_GRW, dtype: int64

# %%
# Standardize name with the most common one: 'Felix Zeloski Farms-Eagle River'
prob_name = df[df["S_GCODE"] == 243]["S_GRW"].unique().tolist()
prob_name
df["S_GRW"] = df["S_GRW"].apply(lambda x: 'Felix Zeloski Farms-Eagle River' if x in prob_name else x)
df["winter_S_GRW"] = df["winter_S_GRW"].apply(lambda x: 'Felix Zeloski Farms-Eagle River' if x in prob_name else x)

# Double check after fixing the problem
grw_count = df[["S_GRW","S_GCODE"]].groupby("S_GCODE").apply(lambda x: x["S_GRW"].nunique())
grw_count[grw_count > 2]
# Out:
# Series([], dtype: int64)

# %%
winter_grw_count = df[["winter_S_GRW","winter_S_GCODE"]].groupby("winter_S_GCODE").apply(lambda x: x["winter_S_GRW"].nunique())
winter_grw_count[winter_grw_count > 2]
# Out:
# Series([], dtype: int64)

# %%
df["S_GRW"].value_counts()
# Out:
# State Farm                             5172
# UW Breeding Sta.                        511
# Felix Zeloski Farms-Eagle River         220
# Uihlein Farm                            159
# Valley TCulture                         133
# Summit Plant Labs, Inc.                 119
# Sklarczyk Seed Farm, LLC                103
# CETS, LLC Astrotuber                    102
# CSS                                      97
# Schroeder Bros., Farms, Inc.             90
# Droge                                    80
# Cornell Uihlein Farm                     66
# John  Miller Farms. Inc.                 39
# Wild Seed Farms, Inc                     34
# Seidl Farms, Inc.                        32
# J.W. Mattek & Sons, Inc.                 30
# Sowinski Farms, Inc.-Cert. Seed          28
# Kent Farms                               27
# Schroeder Farms, Ltd                     26
# Ted Baginski and Sons, Inc.              25
# Rine Ridge Farms, Inc.                   25
# Phytocultures Ltd.                       22
# Jorde, Jim                               20
# Schutter                                 16
# Gallenberg Farms, Inc.                   16
# James Gallenberg                         15
# Thompson Seed Potatoes                   15
# Miller, Henri                            15
# Wirz, Inc.                               15
# Kakes Seed Farms, Ltd.                   14
# Sunny Valley Farms, Inc.                 13
# Hafner Seed Farms, Inc.                  11
# UI/Teutonia                              11
# David Fleischman Farms                    9
# Summit Farms, Inc.                        8
# Sunnydale Farms, Inc.                     8
# Bula Potato Farms, Inc.                   7
# Jorde, Jim  LLP                           7
# Skogman Seed Farm                         7
# Jorde, Mike                               7
# Royce Atwater                             6
# Jorde Certified Seed LLC                  6
# Sunrain Varieties LLC                     6
# Tetonia R & E Center                      6
# Droge Farms Inc                           6
# Nilson Farms                              5
# Hartman Farms, Inc.                       4
# Tony Spychalla Farms, Inc.                4
# Mark Stremick                             4
# Mangel's Seed Potatoes, Inc.              4
# Childstock                                4
# Johnson Foundation Seed Farm LLP          4
# Crown Farms                               3
# Myrna Stremick                            3
# Parkinson Seed Farm- Dirk Parkinson       3
# Phytocultures LTD.                        3
# Jonk Seed Farm Inc                        3
# Technico,Technologies/Shamrock Seed       3
# Diercks & Sons, Inc.                      3
# Guenthner Potato Co., Inc. Antigo         3
# Enander Seed Farm                         3
# Maine Seed Farm                           2
# North Dakota State University             2
# Johnson Farms                             2
# Myrna stremick                            2
# Childstock Farms Inc                      2
# Kamps Seed Farm                           2
# Spring Creedk Farms, Inc.                 2
# Mike Steinmann                            2
# Bjornstad Brothers                        2
# PEI Produce                               2
# Worley Seed                               2
# Haskett Growers Ltd                       2
# Paquin Farms, Inc.                        2
# Haenni Farms                              2
# Miller Farms Inc John                     2
# Nicholes, Justin                          2
# Hanson Seed Farm, LLC                     2
# London Hills                              2
# Neu Ground Labs LLC                       2
# David Gallenberg                          2
# Seed Pro, Inc.                            2
# Montana State University                  1
# Bushman's Riverside Ranch, Inc.           1
# Buyan Ranch, Inc.                         1
# Scidmore Farm                             1
# Golden Eye Seed Farms, Inc.               1
# Betty Kuczmarski & Sons                   1
# San Luis Valley Research Center           1
# McCain  Produce                           1
# London                                    1
# Greenleaf Organics                        1
# Thompson & Sons, Inc. TF                  1
# London Hills Farms                        1
# Larson Farms                              1
# Kroeker Farms, LTD                        1
# Kimm Seed Potatoe                         1
# Ebbensson                                 1
# Mark Kuehl                                1
# Martin Visser and Sons                    1
# Van Erkel Farms, Inc.                     1
# Parkinson Seed Foundation Farm            1
# Name: S_GRW, dtype: int64

# %%
# Three source growers have 2 source grower code

gcode_count = df[["S_GRW","S_GCODE"]].groupby("S_GRW").apply(lambda x: x["S_GCODE"].nunique())
gcode_count[gcode_count > 1]
# Out:
# S_GRW
# CSS                         2
# Jorde Certified Seed LLC    2
# Thompson Seed Potatoes      2
# dtype: int64

# %%
# Look into these three problematic grower
prob_grower = gcode_count[gcode_count > 1].index.tolist()
prob_grower

for grower in prob_grower:
    print(str(grower) +":" + str(df[df["S_GRW"] == grower]["S_GCODE"].unique()))
    print()
# prob_grw = gcode_count[gcode_count > 1].index
# Out:
# CSS:['co26' 'ne06']
#
# Jorde Certified Seed LLC:['nd14' nan 'nd44']
#
# Thompson Seed Potatoes:['ne07' 'ne20']

# %% [markdown]
# #### Possible redundant info for summer and winter
#
# Summer info and winter info should match for source info

# %%
summer_columns = ["CERT_N",
"SNAME",
"GCODE",
"VARIETY",
"S_GRW",
"S_G",
"S_YR",
"S_GCODE",
"S_STATE"]

winter_columns = ["winter_{}".format(x) for x in summer_columns]
winter_columns

combined_columns =[]
for i in range(len(summer_columns)):
    combined_columns.append(summer_columns[i])
    combined_columns.append(winter_columns[i])
    
combined_columns
# Out:
# ['CERT_N',
#  'winter_CERT_N',
#  'SNAME',
#  'winter_SNAME',
#  'GCODE',
#  'winter_GCODE',
#  'VARIETY',
#  'winter_VARIETY',
#  'S_GRW',
#  'winter_S_GRW',
#  'S_G',
#  'winter_S_G',
#  'S_YR',
#  'winter_S_YR',
#  'S_GCODE',
#  'winter_S_GCODE',
#  'S_STATE',
#  'winter_S_STATE']

# %%
df[combined_columns]
# Out:
#       CERT_N  winter_CERT_N      SNAME winter_SNAME GCODE  winter_GCODE  \
# 0     107150       107150.0    Bula Po      Bula Po   114         114.0
# 1     103207       103207.0    Bula Po      Bula Po   114         114.0
# 2     103217       103217.0    Bula Po      Bula Po   114         114.0
# 3     109003       109003.0  Guen Farm    Guen Farm   149         149.0
# 4     109003       109003.0  Guen Farm    Guen Farm   149         149.0
# ...      ...            ...        ...          ...   ...           ...
# 7497  110462       110462.0  Northsand    Northsand   196         196.0
# 7498  108292       108292.0    Bula Po      Bula Po   114         114.0
# 7499  108369       108369.0  Northsand    Northsand   196         196.0
# 7500  108291       108291.0    Bula Po      Bula Po   114         114.0
# 7501  108370       108370.0  Northsand    Northsand   196         196.0
#
#                   VARIETY       winter_VARIETY                    S_GRW  \
# 0     1975-11-15 00:00:00  1975-11-15 00:00:00  Summit Plant Labs, Inc.
# 1               A-88338-1            A-88338-1          Kamps Seed Farm
# 2              A-90586-11           A-90586-11          Kamps Seed Farm
# 3               A-91814-5            A-91814-5               State Farm
# 4               A-91814-5            A-91814-5               State Farm
# ...                   ...                  ...                      ...
# 7497                Zebra                Zebra     CETS, LLC Astrotuber
# 7498                Zebra                Zebra     CETS, LLC Astrotuber
# 7499                Zebra                Zebra     CETS, LLC Astrotuber
# 7500                 Zeus                 Zeus     CETS, LLC Astrotuber
# 7501                 Zeus                 Zeus     CETS, LLC Astrotuber
#
#                  winter_S_GRW          S_G   winter_S_G  S_YR  winter_S_YR  \
# 0     Summit Plant Labs, Inc.  Summit Labs  Summit Labs  2007       2007.0
# 1             Kamps Seed Farm    Manhattan    Manhattan  2003       2003.0
# 2             Kamps Seed Farm    Manhattan    Manhattan  2003       2003.0
# 3                  State Farm   State Farm   State Farm  2009       2009.0
# 4                  State Farm   State Farm   State Farm  2009       2009.0
# ...                       ...          ...          ...   ...          ...
# 7497     CETS, LLC Astrotuber         CETS         CETS  2008       2008.0
# 7498     CETS, LLC Astrotuber         CETS         CETS  2008       2008.0
# 7499     CETS, LLC Astrotuber         CETS         CETS  2008       2008.0
# 7500     CETS, LLC Astrotuber         CETS         CETS  2008       2008.0
# 7501     CETS, LLC Astrotuber         CETS         CETS  2008       2008.0
#
#      S_GCODE winter_S_GCODE S_STATE winter_S_STATE
# 0       co02           co02      CO             CO
# 1       mt14           mt14      MT             MT
# 2       mt14           mt14      MT             MT
# 3          0              0      WI             WI
# 4          0              0      WI             WI
# ...      ...            ...     ...            ...
# 7497      wi             wi      WI             WI
# 7498      wi             wi      WI             WI
# 7499      wi             wi      WI             WI
# 7500      wi             wi      WI             WI
# 7501      wi             wi      WI             WI
#
# [7502 rows x 18 columns]

# %% [markdown]
# ##### Check the reason for mismatch
#
# Some of mismatch result from missing value
#
# Solution: fill the missing value by its equivalent

# %%
conditions = [(df.loc[:, combined_columns[i]] != df.loc[:,combined_columns[i+1]]) for i in range(0,len(combined_columns),2)]
conditions

df.loc[conditions[0] | conditions[1] | conditions[2] | conditions[3] | conditions[4] | conditions[5] | conditions[6] | conditions[7] | conditions[8],combined_columns
      ]
# Out:
#       CERT_N  winter_CERT_N       SNAME winter_SNAME GCODE  winter_GCODE  \
# 10    110329            NaN     Bula Po          NaN   114           NaN
# 11    115135       115135.0     Bula Po      Bula Po   114         114.0
# 13    112348       112348.0     Bula Po      Bula Po   114         114.0
# 16    110333            NaN     Bula Po          NaN   114           NaN
# 42    115254       115254.0     Bula Po      Bula Po   114         114.0
# ...      ...            ...         ...          ...   ...           ...
# 7453  110223            NaN     Vermont          NaN   340           NaN
# 7472  108351       108351.0  Fleischman   Fleischman   133         133.0
# 7473  108351       108351.0  Fleischman   Fleischman   133         133.0
# 7495  110452            NaN   Northsand          NaN   196           NaN
# 7496  110459            NaN   Northsand          NaN   196           NaN
#
#                       VARIETY winter_VARIETY                 S_GRW  \
# 10                   A008-ITE            NaN           UI/Teutonia
# 11    A02507-2LB - Payette Ru     A02507-2LB           UI/Teutonia
# 13                A95109-1RUS    A95409-1RUS           UI/Teutonia
# 16                A95409-1RUS            NaN           UI/Teutonia
# 42                    Actrice        Actrice    Phytocultures Ltd.
# ...                       ...            ...                   ...
# 7453               Yukon Gold            NaN            State Farm
# 7472               Yukon Gold     Yukon Gold            State Farm
# 7473               Yukon Gold     Yukon Gold            State Farm
# 7495                    Zebra            NaN  CETS, LLC Astrotuber
# 7496                    Zebra            NaN  CETS, LLC Astrotuber
#
#             winter_S_GRW          S_G   winter_S_G  S_YR  winter_S_YR S_GCODE  \
# 10                   NaN  UI/Teutonia          NaN  2010          NaN    id01
# 11           UI/Teutonia  UI/Teutonia  UI/Teutonia  2015       2015.0    id01
# 13           UI/Teutonia  UI/Teutonia  UI/Teutonia  2010       2010.0    id01
# 16                   NaN  UI/Teutonia          NaN  2010          NaN    id01
# 42    Phytocultures Ltd.      Phytocu      Phytocu  2015       2015.0   pei05
# ...                  ...          ...          ...   ...          ...     ...
# 7453                 NaN   State Farm          NaN  2009          NaN       0
# 7472          State Farm   State Farm   State Farm  1072       2006.0       0
# 7473          State Farm   State Farm   State Farm  1072       2006.0       0
# 7495                 NaN         CETS          NaN  2010          NaN      wi
# 7496                 NaN         CETS          NaN  2009          NaN      wi
#
#      winter_S_GCODE S_STATE winter_S_STATE
# 10              NaN      ID            NaN
# 11             id01      ID             ID
# 13             id01      ID             ID
# 16              NaN      ID            NaN
# 42            pei05     PEI             PE
# ...             ...     ...            ...
# 7453            NaN      WI            NaN
# 7472              0      WI             WI
# 7473              0      WI             WI
# 7495            NaN      WI            NaN
# 7496            NaN      WI            NaN
#
# [308 rows x 18 columns]

# %% [markdown]
# Fill na value in either summer or winter columns by the other one

# %%
for i in range(0, len(combined_columns),2):
    df[combined_columns[i]] = df[combined_columns[i]].fillna(df[combined_columns[i+1]])
    df[combined_columns[i]] = df[combined_columns[i]].mask(df[combined_columns[i]]==0).fillna(df[combined_columns[i+1]])

for i in range(1, len(combined_columns),2):
    df[combined_columns[i]] = df[combined_columns[i]].fillna(df[combined_columns[i-1]])
    df[combined_columns[i]] =df[combined_columns[i]].mask(df[combined_columns[i]]==0).fillna(df[combined_columns[i-1]])

# %% [markdown]
# ##### Mismatch Analysis
#
# - Reason1: Typo
# - Reason2: full name and shorthand notation in variety
# - Reason3: Extra comma (source grower)

# %%
new_conditions = [(df.loc[:, combined_columns[i]] != df.loc[:,combined_columns[i+1]]) for i in range(0,len(combined_columns),2)]
new_conditions

df.loc[new_conditions[0] | new_conditions[1] | new_conditions[2] | new_conditions[3] | new_conditions[4] | new_conditions[5] | new_conditions[6] | new_conditions[7] | new_conditions[8],combined_columns
      ]
# Out:
#       CERT_N  winter_CERT_N       SNAME winter_SNAME GCODE  winter_GCODE  \
# 11    115135       115135.0     Bula Po      Bula Po   114         114.0
# 13    112348       112348.0     Bula Po      Bula Po   114         114.0
# 42    115254       115254.0     Bula Po      Bula Po   114         114.0
# 127   104379       104379.0   Gall Dave    Gall Dave   145         145.0
# 206   103159       103159.0        Wild         Wild   235         235.0
# ...      ...            ...         ...          ...   ...           ...
# 7306  103418       103418.0     Vermont   D. Perkins   340         340.0
# 7394  113057       113057.0     Bula Po      Bula Po   114         114.0
# 7453  110223       110223.0     Vermont      Vermont   340         340.0
# 7472  108351       108351.0  Fleischman   Fleischman   133         133.0
# 7473  108351       108351.0  Fleischman   Fleischman   133         133.0
#
#                       VARIETY winter_VARIETY                     S_GRW  \
# 11    A02507-2LB - Payette Ru     A02507-2LB               UI/Teutonia
# 13                A95109-1RUS    A95409-1RUS               UI/Teutonia
# 42                    Actrice        Actrice        Phytocultures Ltd.
# 127                  All Blue       All Blue              Uihlein Farm
# 206                  Atlantic       Atlantic  Sklarczyk Seed Farm, LLC
# ...                       ...            ...                       ...
# 7306               Yukon Gold     Yukon Gold                State Farm
# 7394               Yukon Gold     Yukon Gold          James Gallenberg
# 7453               Yukon Gold     Yukon Gold                State Farm
# 7472               Yukon Gold     Yukon Gold                State Farm
# 7473               Yukon Gold     Yukon Gold                State Farm
#
#             winter_S_GRW           S_G    winter_S_G  S_YR  winter_S_YR  \
# 11           UI/Teutonia   UI/Teutonia   UI/Teutonia  2015       2015.0
# 13           UI/Teutonia   UI/Teutonia   UI/Teutonia  2010       2010.0
# 42    Phytocultures Ltd.       Phytocu       Phytocu  2015       2015.0
# 127         Uihlein Farm    Uihlein Fm    Uihlein Fm  2000       2002.0
# 206            Sklarczyk     Sklarczyk     Sklarczyk  2003       2003.0
# ...                  ...           ...           ...   ...          ...
# 7306          State Farm    State Farm    State Farm  2003       2003.0
# 7394    James Gallenberg  J Gallenberg  Gallenberg J  2013       2013.0
# 7453          State Farm    State Farm    State Farm  2009       2009.0
# 7472          State Farm    State Farm    State Farm  1072       2006.0
# 7473          State Farm    State Farm    State Farm  1072       2006.0
#
#      S_GCODE winter_S_GCODE S_STATE winter_S_STATE
# 11      id01           id01      ID             ID
# 13      id01           id01      ID             ID
# 42     pei05          pei05     PEI             PE
# 127     ny01           ny01      NY             NY
# 206     mi01           mi01      MI             MI
# ...      ...            ...     ...            ...
# 7306       0              0      WI             WI
# 7394     142            142      WI             WI
# 7453     NaN            NaN      WI             WI
# 7472       0              0      WI             WI
# 7473       0              0      WI             WI
#
# [274 rows x 18 columns]

# %%
# Number of mismatch after filling missing value

for i in range(len(new_conditions)):
    print(combined_columns[i*2] + ":" + str(len(df.loc[new_conditions[i], combined_columns])))
# Out:
# CERT_N:0
# SNAME:125
# GCODE:1
# VARIETY:109
# S_GRW:71
# S_G:59
# S_YR:62
# S_GCODE:32
# S_STATE:11

# %%
df.loc[df["S_G"] != df["winter_S_G"], combined_columns]
# Out:
#       CERT_N  winter_CERT_N        SNAME winter_SNAME GCODE  winter_GCODE  \
# 339   107359       107359.0    Northsand    Northsand   196         196.0
# 460   111261       111261.0     Sowinski     Sowinski   269         269.0
# 462   111261       111261.0     Sowinski     Sowinski   269         269.0
# 584   113190       113190.0    Schroeder    Schroeder   216         216.0
# 585   113190       113190.0    Schroeder    Schroeder   216         216.0
# 586   113190       113190.0    Schroeder    Schroeder   216         216.0
# 587   113190       113190.0    Schroeder    Schroeder   216         216.0
# 588   113190       113190.0    Schroeder    Schroeder   216         216.0
# 589   113190       113190.0    Schroeder    Schroeder   216         216.0
# 590   113190       113190.0    Schroeder    Schroeder   216         216.0
# 591   113190       113190.0    Schroeder    Schroeder   216         216.0
# 996   106004       106004.0        Kakes        Kakes   162         162.0
# 1115  104119       104119.0       Mattek       Mattek   190         190.0
# 1116  104119       104119.0       Mattek       Mattek   190         190.0
# 1161  105347       105347.0    Gall Dave    Gall Dave   145         145.0
# 1219  107154       107154.0      Bula Po      Bula Po   114         114.0
# 1230  107296       107296.0    Gall Dave    Gall Dave   145         145.0
# 1376  111384       111384.0    Gall Dave    Gall Dave   145         145.0
# 1435  112275       112275.0    Gall Dave    Gall Dave   145         145.0
# 1499  113356       113356.0    Gall Dave    Gall Dave   145         145.0
# 1624  110423       110423.0    Gall Dave    Gall Dave   145         145.0
# 1666  106101       106101.0    Gall Farm    Gall Farm   144         144.0
# 1667  106101       106101.0    Gall Farm    Gall Farm   144         144.0
# 1675  106084       106084.0    Gall Dave    Gall Dave   145         145.0
# 1701  106348       106348.0    Schroeder    Schroeder   216         216.0
# 1702  106348       106348.0    Schroeder    Schroeder   216         216.0
# 1743  108315       108315.0    Gall Dave    Gall Dave   145         145.0
# 1920  113194       113194.0    Schroeder    Schroeder   216         216.0
# 1932  103025       103025.0    Gall Farm    Gall Farm   144         144.0
# 2012  104374       104374.0      Hartman      Hartman   154         154.0
# 2132  109234       109234.0      Bula Po   State Farm   114         114.0
# 2557  108414       108414.0        Misco        Misco   280         280.0
# 2879  104142       104142.0    Rineridge    Rineridge   259         259.0
# 3261  105040       105040.0        Kakes        Kakes   162         162.0
# 3526  107360       107360.0    Northsand    Northsand   196         196.0
# 3658  113264       113264.0         Wirz         Wirz   236         236.0
# 3821  103174       103174.0    Rineridge    Rineridge   259         259.0
# 4572  107358       107358.0    Northsand    Northsand   196         196.0
# 4684  104375       104375.0      Hartman      Hartman   154         154.0
# 4685  104376       104376.0      Hartman      Hartman   154         154.0
# 4787  107361       107361.0    Northsand    Northsand   196         196.0
# 4840  111011       111011.0       Hafner   State Farm   151         151.0
# 4841  111011       111011.0       Hafner   State Farm   151         151.0
# 5234  107357       107357.0    Northsand    Northsand   196         196.0
# 5236  109387       109387.0    Northsand    Northsand   196         196.0
# 5345  112208       112208.0    Schroeder    Schroeder   216         216.0
# 5346  112208       112208.0    Schroeder    Schroeder   216         216.0
# 5347  112208       112208.0    Schroeder    Schroeder   216         216.0
# 5348  112208       112208.0    Schroeder    Schroeder   216         216.0
# 5625  107153       107153.0      Bula Po      Bula Po   114         114.0
# 5640  107356       107356.0    Northsand    Northsand   196         196.0
# 5815  112201       112201.0    Schroeder    Schroeder   216         216.0
# 5816  112201       112201.0    Schroeder    Schroeder   216         216.0
# 5817  112201       112201.0    Schroeder    Schroeder   216         216.0
# 5818  112201       112201.0    Schroeder    Schroeder   216         216.0
# 6546  113072       113072.0      Bula Po      Bula Po   114         114.0
# 6810  106055       106055.0  Uw Potato R  Uw Potato R     1           1.0
# 7263  107152       107152.0      Bula Po      Bula Po   114         114.0
# 7394  113057       113057.0      Bula Po      Bula Po   114         114.0
#
#                 VARIETY         winter_VARIETY  \
# 339            Atlantic               Atlantic
# 460            Atlantic               Atlantic
# 462            Atlantic               Atlantic
# 584            Atlantic               Atlantic
# 585            Atlantic               Atlantic
# 586            Atlantic               Atlantic
# 587            Atlantic               Atlantic
# 588            Atlantic               Atlantic
# 589            Atlantic               Atlantic
# 590            Atlantic               Atlantic
# 591            Atlantic               Atlantic
# 996        Dakota Crisp           Dakota Crisp
# 1115   Dark Red Norland       Dark Red Norland
# 1116   Dark Red Norland       Dark Red Norland
# 1161   Dark Red Norland       Dark Red Norland
# 1219   Dark Red Norland       Dark Red Norland
# 1230   Dark Red Norland       Dark Red Norland
# 1376   Dark Red Norland       Dark Red Norland
# 1435   Dark Red Norland       Dark Red Norland
# 1499   Dark Red Norland       Dark Red Norland
# 1624   Dark Red Norland       Dark Red Norland
# 1666   Dark Red Norland       Dark Red Norland
# 1667   Dark Red Norland       Dark Red Norland
# 1675   Dark Red Norland       Dark Red Norland
# 1701   Dark Red Norland       Dark Red Norland
# 1702   Dark Red Norland       Dark Red Norland
# 1743   Dark Red Norland       Dark Red Norland
# 1920               Gala                   Gala
# 1932  German Butterball      German Butterball
# 2012           Goldrush               Goldrush
# 2132           Goldrush  Russet Norkotah Sel 8
# 2557           Goldrush               Goldrush
# 2879          Mega chip              Mega chip
# 3261         ND 2470-27             ND 2470-27
# 3526               Pike                   Pike
# 3658               Pike                   Pike
# 3821               Reba                   Reba
# 4572     Russet Burbank         Russet Burbank
# 4684    Russet Norkotah        Russet Norkotah
# 4685    Russet Norkotah        Russet Norkotah
# 4787    Russet Norkotah        Russet Norkotah
# 4840    Russet Norkotah               Goldrush
# 4841    Russet Norkotah               Goldrush
# 5234            Shepody                Shepody
# 5236            Shepody                Shepody
# 5345          Silverton              Silverton
# 5346          Silverton              Silverton
# 5347          Silverton              Silverton
# 5348          Silverton              Silverton
# 5625            Snowden                Snowden
# 5640            Snowden                Snowden
# 5815            Snowden                Snowden
# 5816            Snowden                Snowden
# 5817            Snowden                Snowden
# 5818            Snowden                Snowden
# 6546            Sylvana                Sylvana
# 6810         W1879-1RUS             W1879-1RUS
# 7263        White Pearl            White Pearl
# 7394         Yukon Gold             Yukon Gold
#
#                                 S_GRW                 winter_S_GRW  \
# 339              CETS, LLC Astrotuber                CETSTECH, LLC
# 460   Felix Zeloski Farms-Eagle River                   State Farm
# 462   Felix Zeloski Farms-Eagle River                   State Farm
# 584              Schroeder Farms, Ltd          Schroder Farms Ltd.
# 585              Schroeder Farms, Ltd          Schroder Farms Ltd.
# 586              Schroeder Farms, Ltd          Schroder Farms Ltd.
# 587              Schroeder Farms, Ltd          Schroder Farms Ltd.
# 588              Schroeder Farms, Ltd          Schroder Farms Ltd.
# 589              Schroeder Farms, Ltd          Schroder Farms Ltd.
# 590              Schroeder Farms, Ltd          Schroder Farms Ltd.
# 591              Schroeder Farms, Ltd          Schroder Farms Ltd.
# 996                      Nilson Farms                 Nilson Farms
# 1115      Ted Baginski and Sons, Inc.  Ted Baginski and Sons, Inc.
# 1116      Ted Baginski and Sons, Inc.  Ted Baginski and Sons, Inc.
# 1161                 James Gallenberg             James Gallenberg
# 1219             CETS, LLC Astrotuber                CETSTECH, LLC
# 1230                 James Gallenberg             James Gallenberg
# 1376                 James Gallenberg             James Gallenberg
# 1435                 James Gallenberg             James Gallenberg
# 1499                 James Gallenberg             James Gallenberg
# 1624                 James Gallenberg             James Gallenberg
# 1666                 James Gallenberg             James Gallenberg
# 1667                 James Gallenberg             James Gallenberg
# 1675                 James Gallenberg             James Gallenberg
# 1701  Felix Zeloski Farms-Eagle River                   State Farm
# 1702  Felix Zeloski Farms-Eagle River                   State Farm
# 1743                 James Gallenberg             James Gallenberg
# 1920             Schroeder Farms, Ltd          Schroder Farms Ltd.
# 1932                 David Gallenberg             David Gallenberg
# 2012      Ted Baginski and Sons, Inc.  Ted Baginski and Sons, Inc.
# 2132                Seidl Farms, Inc.                   State Farm
# 2557           Gallenberg Farms, Inc.        Guenthner Farms, Inc.
# 2879                       State Farm                   State Farm
# 3261                     Nilson Farms                 Nilson Farms
# 3526             CETS, LLC Astrotuber                CETSTECH, LLC
# 3658             Schroeder Farms, Ltd          Schroder Farms Ltd.
# 3821                    Royce Atwater                Royce Atwater
# 4572             CETS, LLC Astrotuber                CETSTECH, LLC
# 4684           David Fleischman Farms       David Fleischman Farms
# 4685           David Fleischman Farms       David Fleischman Farms
# 4787             CETS, LLC Astrotuber                CETSTECH, LLC
# 4840                            Droge                   State Farm
# 4841                            Droge                   State Farm
# 5234             CETS, LLC Astrotuber                CETSTECH, LLC
# 5236                  Valley TCulture        Valley Tissue Culture
# 5345             Schroeder Farms, Ltd          Schroder Farms Ltd.
# 5346             Schroeder Farms, Ltd          Schroder Farms Ltd.
# 5347             Schroeder Farms, Ltd          Schroder Farms Ltd.
# 5348             Schroeder Farms, Ltd          Schroder Farms Ltd.
# 5625             CETS, LLC Astrotuber                CETSTECH, LLC
# 5640             CETS, LLC Astrotuber                CETSTECH, LLC
# 5815             Schroeder Farms, Ltd          Schroder Farms Ltd.
# 5816             Schroeder Farms, Ltd          Schroder Farms Ltd.
# 5817             Schroeder Farms, Ltd          Schroder Farms Ltd.
# 5818             Schroeder Farms, Ltd          Schroder Farms Ltd.
# 6546               Phytocultures LTD.           Phytocultures LTD.
# 6810                 UW Breeding Sta.             UW Breeding Sta.
# 7263             CETS, LLC Astrotuber                CETSTECH, LLC
# 7394                 James Gallenberg             James Gallenberg
#
#                  S_G       winter_S_G  S_YR  winter_S_YR S_GCODE  \
# 339             CETS             Cets  2007       2007.0      wi
# 460      Zeloski -ER       State Farm  2010       2010.0     243
# 462      Zeloski -ER       State Farm  2010       2010.0     243
# 584   Schroeder Farm   Schroder Farms  2013       2013.0     217
# 585   Schroeder Farm   Schroder Farms  2013       2013.0     217
# 586   Schroeder Farm   Schroder Farms  2013       2013.0     217
# 587   Schroeder Farm   Schroder Farms  2013       2013.0     217
# 588   Schroeder Farm   Schroder Farms  2013       2013.0     217
# 589   Schroeder Farm   Schroder Farms  2013       2013.0     217
# 590   Schroeder Farm   Schroder Farms  2013       2013.0     217
# 591   Schroeder Farm   Schroder Farms  2013       2013.0     217
# 996     Nilson Farms      Nilson Farm  2005       2005.0    nd39
# 1115        Baginski       T Baginski  2004       2004.0     108
# 1116        Baginski       T Baginski  2004       2004.0     108
# 1161    J Gallenberg     Gallenberg J  2004       2004.0     142
# 1219            CETS             Cets  2007       2007.0      wi
# 1230    J Gallenberg     Gallenberg J  2006       2006.0     142
# 1376    J Gallenberg     Gallenberg J  2011       2011.0     142
# 1435    J Gallenberg     Gallenberg J  2012       2012.0     142
# 1499    J Gallenberg     Gallenberg J  2013       2013.0     142
# 1624    J Gallenberg     Gallenberg J  2009       2009.0     142
# 1666    J Gallenberg     Gallenberg J  2006       2006.0     142
# 1667    J Gallenberg     Gallenberg J  2006       2006.0     142
# 1675    J Gallenberg     Gallenberg J  2006       2006.0     142
# 1701     Zeloski -ER       State Farm  2004       2004.0     243
# 1702     Zeloski -ER       State Farm  2004       2004.0     243
# 1743    J Gallenberg     Gallenberg J  2005       2005.0     142
# 1920  Schroeder Farm   Schroder Farms  2013       2013.0     217
# 1932    Gallenberg D     D Gallenberg  2003       2003.0     145
# 2012        Baginski       T Baginski  2004       2004.0     108
# 2132           Seidl       State Farm  2009       2009.0     268
# 2557  Gallenberg Fms    Guenthner Fms  2008       2008.0     144
# 2879      State Farm      UW Breeding  2002       2002.0       1
# 3261    Nilson Farms      Nilson Farm  2005       2005.0    nd39
# 3526            CETS             Cets  2007       2007.0      wi
# 3658  Schroeder Farm   Schroder Farms  2013       2013.0     217
# 3821   Royce Atwater            Salen  2003       2003.0    ny06
# 4572            CETS             Cets  2007       2007.0      wi
# 4684    Fleischman D      D Fleischmn  2004       2004.0     133
# 4685    Fleischman D      D Fleischmn  2004       2004.0     133
# 4787            CETS             Cets  2007       2007.0      wi
# 4840           Droge       State Farm  2011       2009.0    mt05
# 4841           Droge       State Farm  2011       2009.0    mt05
# 5234            CETS             Cets  2007       2007.0      wi
# 5236    Val TCulture    Val T Culture  2009       2009.0    mn11
# 5345  Schroeder Farm   Schroder Farms  2011       2011.0     217
# 5346  Schroeder Farm   Schroder Farms  2011       2011.0     217
# 5347  Schroeder Farm   Schroder Farms  2011       2011.0     217
# 5348  Schroeder Farm   Schroder Farms  2011       2011.0     217
# 5625            CETS             Cets  2007       2007.0      wi
# 5640            CETS             Cets  2007       2007.0      wi
# 5815  Schroeder Farm   Schroder Farms  2011       2011.0     217
# 5816  Schroeder Farm   Schroder Farms  2011       2011.0     217
# 5817  Schroeder Farm   Schroder Farms  2011       2011.0     217
# 5818  Schroeder Farm   Schroder Farms  2011       2011.0     217
# 6546         Phytocu    Phytocultures  2013       2013.0   pei05
# 6810     UW Breeding  UW BUW Breeding  2006       2006.0       1
# 7263            CETS             Cets  2007       2007.0      wi
# 7394    J Gallenberg     Gallenberg J  2013       2013.0     142
#
#      winter_S_GCODE S_STATE winter_S_STATE
# 339              wi      WI             WI
# 460             243      WI             WI
# 462             243      WI             WI
# 584             217      WI             WI
# 585             217      WI             WI
# 586             217      WI             WI
# 587             217      WI             WI
# 588             217      WI             WI
# 589             217      WI             WI
# 590             217      WI             WI
# 591             217      WI             WI
# 996            nd35      ND             ND
# 1115            108      WI             WI
# 1116            108      WI             WI
# 1161            142      WI             WI
# 1219             wi      WI             WI
# 1230            142      WI             WI
# 1376            142      WI             WI
# 1435            142      WI             WI
# 1499            142      WI             WI
# 1624            142      WI             WI
# 1666            142      WI             WI
# 1667            142      WI             WI
# 1675            142      WI             WI
# 1701            243      WI             WI
# 1702            243      WI             WI
# 1743            142      WI             WI
# 1920            217      WI             WI
# 1932            145      WI             WI
# 2012            108      WI             WI
# 2132            268      WI             WI
# 2557            149      WI             WI
# 2879              1      WI             WI
# 3261           nd35      ND             ND
# 3526             wi      WI             WI
# 3658            217      WI             WI
# 3821           ny06      NY             NY
# 4572             wi      WI             WI
# 4684            133      WI             WI
# 4685            133      WI             WI
# 4787             wi      WI             WI
# 4840           mt05      MT             WI
# 4841           mt05      MT             WI
# 5234             wi      WI             WI
# 5236           mn11      MN             MN
# 5345            217      WI             WI
# 5346            217      WI             WI
# 5347            217      WI             WI
# 5348            217      WI             WI
# 5625             wi      WI             WI
# 5640             wi      WI             WI
# 5815            217      WI             WI
# 5816            217      WI             WI
# 5817            217      WI             WI
# 5818            217      WI             WI
# 6546          pei05      PE             PE
# 6810              1      WI             WI
# 7263             wi      WI             WI
# 7394            142      WI             WI

# %%
df["S_G"].value_counts()
# Out:
# State Farm        5172
# UW Breeding        511
# Uihlein Fm         225
# Zeloski -ER        207
# Val TCulture       133
# Summit Labs        119
# Sklarczyk          103
# CETS               102
# CSS                 97
# Schroeder Bros      90
# Droge               80
# John Miller         39
# Wild                34
# Seidl               32
# Mattek              30
# Sowinski            28
# Kent Farms          27
# J Jorde             27
# Schroeder Farm      26
# Rine Ridge          25
# Baginski            25
# Phytocu             23
# Schutter            16
# Thompson            16
# Gallenberg Fms      16
# H Miller            15
# Wirz                15
# Kakes               14
# J Gallenberg        13
# Sunny Valley        13
# UI/Teutonia         11
# Hafner              11
# Eagle River Se      11
# Fleischman D         9
# Summit Farms         8
# Sunnydale            8
# Jorde Mike           7
# Skogman              7
# Bula Potato          7
# Childstock           6
# Droge Farms          6
# Johnson              6
# Sunrain Variet       6
# Tetonia              6
# Nilson Farms         5
# Jorde Certi          5
# Mark Stremick        4
# T Spychalla          4
# Parkinson Seed       4
# Hartman              4
# Mangels              4
# Salen                4
# Myrna Stremick       3
# Crown                3
# Enander              3
# Guenthner Po         3
# Diercks              3
# Technico/Sham        3
# Jonk Seed Farm       3
# Neu Ground Lab       2
# J Nicholes           2
# Worley               2
# Hanson               2
# Miller Farms J       2
# Bjornstad            2
# Phytocultures        2
# Seed Pro             2
# Gallenberg J         2
# Sping Creek          2
# Steinmann            2
# Paquin               2
# NDS                  2
# PEI Produce          2
# Manhattan            2
# Haskett              2
# LHIlls               2
# Myrna stremick       2
# Zeloski, Felix       2
# Gallenberg D         2
# Maine Seed           2
# Haenni Farms         2
# London Hill          1
# Buyan                1
# Bushman              1
# Greenleaf Org        1
# B Kuczmarski         1
# Scidmore Farms       1
# Goldeneye            1
# Van Erkel            1
# San Luis             1
# Kimm Pot             1
# Mark Kuehl           1
# Kroeker Farms,       1
# Jorde Certifie       1
# Martin               1
# Larson Farms         1
# London               1
# McCain               1
# Ebbesson             1
# Royce Atwater        1
# MSU                  1
# Atwater              1
# Name: S_G, dtype: int64

# %% [markdown]
# Fix the problem of S_G:
#
# - Upper case and lower case (CETS and Cets) Cets => CETS
# - Plural and singular forms (Nilson Farms & Nilson Farm)
# - Spelling error (Schroeder Farm, Schroder Farms) Schroder Farms => Schroeder Farm
# - Order (J Gallenberg, Gallenberg J)

# %%
df["winter_S_G"] = df["winter_S_G"].apply(lambda x: "CETS" if x == "Cets" else x)

df["winter_S_G"] = df["winter_S_G"].apply(lambda x: "Schroeder Farm" if x == "Schroder Farms" else x)

df["winter_S_G"] = df["winter_S_G"].apply(lambda x: "J Gallenberg" if x == "Gallenberg J" else x)

# %%
df.loc[df["S_G"] != df["winter_S_G"], combined_columns]
# Out:
#       CERT_N  winter_CERT_N        SNAME winter_SNAME GCODE  winter_GCODE  \
# 460   111261       111261.0     Sowinski     Sowinski   269         269.0
# 462   111261       111261.0     Sowinski     Sowinski   269         269.0
# 996   106004       106004.0        Kakes        Kakes   162         162.0
# 1115  104119       104119.0       Mattek       Mattek   190         190.0
# 1116  104119       104119.0       Mattek       Mattek   190         190.0
# 1550  114228       114228.0  Gall Dave &  Gall Dave &   145         145.0
# 1701  106348       106348.0    Schroeder    Schroeder   216         216.0
# 1702  106348       106348.0    Schroeder    Schroeder   216         216.0
# 1932  103025       103025.0    Gall Farm    Gall Farm   144         144.0
# 2012  104374       104374.0      Hartman      Hartman   154         154.0
# 2132  109234       109234.0      Bula Po   State Farm   114         114.0
# 2557  108414       108414.0        Misco        Misco   280         280.0
# 2879  104142       104142.0    Rineridge    Rineridge   259         259.0
# 3261  105040       105040.0        Kakes        Kakes   162         162.0
# 3821  103174       103174.0    Rineridge    Rineridge   259         259.0
# 4684  104375       104375.0      Hartman      Hartman   154         154.0
# 4685  104376       104376.0      Hartman      Hartman   154         154.0
# 4840  111011       111011.0       Hafner   State Farm   151         151.0
# 4841  111011       111011.0       Hafner   State Farm   151         151.0
# 5236  109387       109387.0    Northsand    Northsand   196         196.0
# 6546  113072       113072.0      Bula Po      Bula Po   114         114.0
# 6810  106055       106055.0  Uw Potato R  Uw Potato R     1           1.0
# 7408  114068       114068.0      Bula Po      Bula Po   114         114.0
#
#                 VARIETY         winter_VARIETY  \
# 460            Atlantic               Atlantic
# 462            Atlantic               Atlantic
# 996        Dakota Crisp           Dakota Crisp
# 1115   Dark Red Norland       Dark Red Norland
# 1116   Dark Red Norland       Dark Red Norland
# 1550   Dark Red Norland       Dark Red Norland
# 1701   Dark Red Norland       Dark Red Norland
# 1702   Dark Red Norland       Dark Red Norland
# 1932  German Butterball      German Butterball
# 2012           Goldrush               Goldrush
# 2132           Goldrush  Russet Norkotah Sel 8
# 2557           Goldrush               Goldrush
# 2879          Mega chip              Mega chip
# 3261         ND 2470-27             ND 2470-27
# 3821               Reba                   Reba
# 4684    Russet Norkotah        Russet Norkotah
# 4685    Russet Norkotah        Russet Norkotah
# 4840    Russet Norkotah               Goldrush
# 4841    Russet Norkotah               Goldrush
# 5236            Shepody                Shepody
# 6546            Sylvana                Sylvana
# 6810         W1879-1RUS             W1879-1RUS
# 7408         Yukon Gold             Yukon Gold
#
#                                 S_GRW                 winter_S_GRW  \
# 460   Felix Zeloski Farms-Eagle River                   State Farm
# 462   Felix Zeloski Farms-Eagle River                   State Farm
# 996                      Nilson Farms                 Nilson Farms
# 1115      Ted Baginski and Sons, Inc.  Ted Baginski and Sons, Inc.
# 1116      Ted Baginski and Sons, Inc.  Ted Baginski and Sons, Inc.
# 1550                 James Gallenberg             James Gallenberg
# 1701  Felix Zeloski Farms-Eagle River                   State Farm
# 1702  Felix Zeloski Farms-Eagle River                   State Farm
# 1932                 David Gallenberg             David Gallenberg
# 2012      Ted Baginski and Sons, Inc.  Ted Baginski and Sons, Inc.
# 2132                Seidl Farms, Inc.                   State Farm
# 2557           Gallenberg Farms, Inc.        Guenthner Farms, Inc.
# 2879                       State Farm                   State Farm
# 3261                     Nilson Farms                 Nilson Farms
# 3821                    Royce Atwater                Royce Atwater
# 4684           David Fleischman Farms       David Fleischman Farms
# 4685           David Fleischman Farms       David Fleischman Farms
# 4840                            Droge                   State Farm
# 4841                            Droge                   State Farm
# 5236                  Valley TCulture        Valley Tissue Culture
# 6546               Phytocultures LTD.           Phytocultures LTD.
# 6810                 UW Breeding Sta.             UW Breeding Sta.
# 7408                 James Gallenberg             James Gallenberg
#
#                  S_G       winter_S_G  S_YR  winter_S_YR S_GCODE  \
# 460      Zeloski -ER       State Farm  2010       2010.0     243
# 462      Zeloski -ER       State Farm  2010       2010.0     243
# 996     Nilson Farms      Nilson Farm  2005       2005.0    nd39
# 1115        Baginski       T Baginski  2004       2004.0     108
# 1116        Baginski       T Baginski  2004       2004.0     108
# 1550    Gallenberg J     J Gallenberg  2013       2013.0     142
# 1701     Zeloski -ER       State Farm  2004       2004.0     243
# 1702     Zeloski -ER       State Farm  2004       2004.0     243
# 1932    Gallenberg D     D Gallenberg  2003       2003.0     145
# 2012        Baginski       T Baginski  2004       2004.0     108
# 2132           Seidl       State Farm  2009       2009.0     268
# 2557  Gallenberg Fms    Guenthner Fms  2008       2008.0     144
# 2879      State Farm      UW Breeding  2002       2002.0       1
# 3261    Nilson Farms      Nilson Farm  2005       2005.0    nd39
# 3821   Royce Atwater            Salen  2003       2003.0    ny06
# 4684    Fleischman D      D Fleischmn  2004       2004.0     133
# 4685    Fleischman D      D Fleischmn  2004       2004.0     133
# 4840           Droge       State Farm  2011       2009.0    mt05
# 4841           Droge       State Farm  2011       2009.0    mt05
# 5236    Val TCulture    Val T Culture  2009       2009.0    mn11
# 6546         Phytocu    Phytocultures  2013       2013.0   pei05
# 6810     UW Breeding  UW BUW Breeding  2006       2006.0       1
# 7408    Gallenberg J     J Gallenberg  2013       2013.0     142
#
#      winter_S_GCODE S_STATE winter_S_STATE
# 460             243      WI             WI
# 462             243      WI             WI
# 996            nd35      ND             ND
# 1115            108      WI             WI
# 1116            108      WI             WI
# 1550            142      WI             WI
# 1701            243      WI             WI
# 1702            243      WI             WI
# 1932            145      WI             WI
# 2012            108      WI             WI
# 2132            268      WI             WI
# 2557            149      WI             WI
# 2879              1      WI             WI
# 3261           nd35      ND             ND
# 3821           ny06      NY             NY
# 4684            133      WI             WI
# 4685            133      WI             WI
# 4840           mt05      MT             WI
# 4841           mt05      MT             WI
# 5236           mn11      MN             MN
# 6546          pei05      PE             PE
# 6810              1      WI             WI
# 7408            142      WI             WI

# %% [markdown]
# Fix the problem of S_STATE:
#
# - change PEI to PE

# %%
df["S_STATE"] = df["S_STATE"].apply(lambda x:"PE" if x == "PEI" else x)
df["S_STATE"]
# Out:
# 0       CO
# 1       MT
# 2       MT
# 3       WI
# 4       WI
#         ..
# 7497    WI
# 7498    WI
# 7499    WI
# 7500    WI
# 7501    WI
# Name: S_STATE, Length: 7502, dtype: object

# %% [markdown]
# Fix the problem of S_YR:
#
# - change 1072 (Typo) to 2006

# %%
df["S_YR"] = df["S_YR"].apply(lambda x:2006 if x == 1072 else x)
df["S_YR"]
# Out:
# 0       2007
# 1       2003
# 2       2003
# 3       2009
# 4       2009
#         ...
# 7497    2008
# 7498    2008
# 7499    2008
# 7500    2008
# 7501    2008
# Name: S_YR, Length: 7502, dtype: int64

# %%
df.loc[df["S_YR"] != df["winter_S_YR"], combined_columns]
# Out:
#       CERT_N  winter_CERT_N      SNAME winter_SNAME GCODE  winter_GCODE  \
# 127   104379       104379.0  Gall Dave    Gall Dave   145         145.0
# 405   111009       111009.0     Hafner   State Farm   151         151.0
# 407   111002       111002.0     Hafner   State Farm   151         151.0
# 489   111041       111041.0       Wirz   State Farm   236         236.0
# 490   111041       111041.0       Wirz   State Farm   236         236.0
# 514   112798       112798.0  Northsand    Northsand   196         196.0
# 515   112798       112798.0  Northsand    Northsand   196         196.0
# 2206  111127       111127.0  Gall Farm    Gall Farm   144         144.0
# 2212  111012       111012.0     Hafner   State Farm   151         151.0
# 2214  111004       111004.0     Hafner   State Farm   151         151.0
# 2217  111016       111016.0      Kakes   State Farm   162         162.0
# 2219  111016       111016.0      Kakes   State Farm   162         162.0
# 2945  111020       111020.0      Kakes   State Farm   162         162.0
# 2971  111042       111042.0       Wirz   State Farm   236         236.0
# 2972  111042       111042.0       Wirz   State Farm   236         236.0
# 2973  111042       111042.0       Wirz   State Farm   236         236.0
# 2974  111042       111042.0       Wirz   State Farm   236         236.0
# 2976  111042       111042.0       Wirz   State Farm   236         236.0
# 2977  111042       111042.0       Wirz   State Farm   236         236.0
# 2978  111042       111042.0       Wirz   State Farm   236         236.0
# 3272  111045       111045.0  Rineridge   State Farm   259         259.0
# 3274  111045       111045.0  Rineridge   State Farm   259         259.0
# 3275  111045       111045.0  Rineridge   State Farm   259         259.0
# 3276  111045       111045.0  Rineridge   State Farm   259         259.0
# 3280  111029       111029.0       Wirz   State Farm   236         236.0
# 3608  111030       111030.0       Wirz   State Farm   236         236.0
# 3609  111044       111044.0       Wirz   State Farm   236         236.0
# 3610  111044       111044.0       Wirz   State Farm   236         236.0
# 3612  111044       111044.0       Wirz   State Farm   236         236.0
# 4276  111015       111015.0     Hafner   State Farm   151         151.0
# 4277  111005       111005.0     Hafner   State Farm   151         151.0
# 4805  109206       109206.0   Baginski     Baginski   108         108.0
# 4806  109206       109206.0   Baginski     Baginski   108         108.0
# 4837  111010       111010.0     Hafner   State Farm   151         151.0
# 4840  111011       111011.0     Hafner   State Farm   151         151.0
# 4841  111011       111011.0     Hafner   State Farm   151         151.0
# 4844  111003       111003.0     Hafner   State Farm   151         151.0
# 5316  111007       111007.0     Hafner   State Farm   151         151.0
# 5318  111007       111007.0     Hafner   State Farm   151         151.0
# 5534  103088       103088.0  Sunnydale    Sunnydale   266         266.0
# 5707  111013       111013.0     Hafner   State Farm   151         151.0
# 5708  111013       111013.0     Hafner   State Farm   151         151.0
# 5712  111006       111006.0     Hafner   State Farm   151         151.0
# 5714  111021       111021.0      Kakes   State Farm   162         162.0
# 5758  111023       111023.0       Wirz   State Farm   236         236.0
# 5759  111023       111023.0       Wirz   State Farm   236         236.0
# 5761  111023       111023.0       Wirz   State Farm   236         236.0
# 5770  111028       111028.0       Wirz   State Farm   236         236.0
# 5772  111028       111028.0       Wirz   State Farm   236         236.0
# 5780  111040       111040.0       Wirz   State Farm   236         236.0
# 5781  111040       111040.0       Wirz   State Farm   236         236.0
# 5783  111040       111040.0       Wirz   State Farm   236         236.0
# 5784  111040       111040.0       Wirz   State Farm   236         236.0
# 6286  111008       111008.0     Hafner   State Farm   151         151.0
# 6289  111001       111001.0     Hafner   State Farm   151         151.0
# 6302  111043       111043.0       Wirz   State Farm   236         236.0
# 6303  111043       111043.0       Wirz   State Farm   236         236.0
# 6304  111043       111043.0       Wirz   State Farm   236         236.0
# 6306  111043       111043.0       Wirz   State Farm   236         236.0
# 6906  111047       111047.0  Rineridge   State Farm   259         259.0
#
#               VARIETY             winter_VARIETY  \
# 127          All Blue                   All Blue
# 405          Atlantic        Dark Red Norland Z2
# 407          Atlantic                    Nicolet
# 489          Atlantic                    Snowden
# 490          Atlantic                    Snowden
# 514          Atlantic                   Atlantic
# 515          Atlantic                   Atlantic
# 2206         Goldrush                   Goldrush
# 2212         Goldrush                   Langlade
# 2214         Goldrush                Red Pontiac
# 2217         Goldrush                    Snowden
# 2219         Goldrush                    Snowden
# 2945         MegaChip                      W2324
# 2971         MegaChip                   Superior
# 2972         MegaChip                   Superior
# 2973         MegaChip                   Superior
# 2974         MegaChip                   Superior
# 2976         MegaChip                   Superior
# 2977         MegaChip               Superior-NFT
# 2978         MegaChip                   Superior
# 3272          Nicolet                      W2717
# 3274          Nicolet                      W2717
# 3275          Nicolet                      W2717
# 3276          Nicolet                      W2717
# 3280          Nicolet                   Langlade
# 3608             Pike                   MegaChip
# 3609             Pike                      W2310
# 3610             Pike                      W2310
# 3612             Pike                      W2310
# 4276      Red Norland                Red Norland
# 4277      Red Norland              Russet Sebago
# 4805  Russet Norkotah            Russet Norkotah
# 4806  Russet Norkotah            Russet Norkotah
# 4837  Russet Norkotah             Freedom Russet
# 4840  Russet Norkotah                   Goldrush
# 4841  Russet Norkotah                   Goldrush
# 4844  Russet Norkotah             Russet Burbank
# 5316        Silverton                   Atlantic
# 5318        Silverton                   Atlantic
# 5534          Snowden                    Snowden
# 5707          Snowden                   MegaChip
# 5708          Snowden                   MegaChip
# 5712          Snowden                      W2324
# 5714          Snowden                 Yukon Gold
# 5758          Snowden      Russet Norkotah Sel 8
# 5759          Snowden  Russet Norkotah Sel 8-NFT
# 5761          Snowden      Russet Norkotah Sel 8
# 5770          Snowden                   Kennebec
# 5772          Snowden                   Kennebec
# 5780          Snowden                  Silverton
# 5781          Snowden              Silverton-NFT
# 5783          Snowden              Silverton-NFT
# 5784          Snowden                  Silverton
# 6286         Superior           Dark Red Norland
# 6289         Superior                   Kennebec
# 6302         Superior                      W2133
# 6303         Superior                      W2133
# 6304         Superior                      W2133
# 6306         Superior                      W2133
# 6906          W2324-1                 Yukon Gold
#
#                              S_GRW                  winter_S_GRW  \
# 127                   Uihlein Farm                  Uihlein Farm
# 405                     State Farm                    State Farm
# 407                     State Farm                    State Farm
# 489                     State Farm                    State Farm
# 490                     State Farm                    State Farm
# 514                     State Farm                    State Farm
# 515                     State Farm                    State Farm
# 2206                    State Farm                    State Farm
# 2212                    State Farm                    State Farm
# 2214                    State Farm                    State Farm
# 2217                    State Farm                    State Farm
# 2219                    State Farm                    State Farm
# 2945                    State Farm                    State Farm
# 2971                    State Farm                    State Farm
# 2972                    State Farm                    State Farm
# 2973                    State Farm                    State Farm
# 2974                    State Farm                    State Farm
# 2976                    State Farm                    State Farm
# 2977                    State Farm                    State Farm
# 2978                    State Farm                    State Farm
# 3272                    State Farm                    State Farm
# 3274                    State Farm                    State Farm
# 3275                    State Farm                    State Farm
# 3276                    State Farm                    State Farm
# 3280                    State Farm                    State Farm
# 3608                    State Farm                    State Farm
# 3609                    State Farm                    State Farm
# 3610                    State Farm                    State Farm
# 3612                    State Farm                    State Farm
# 4276                    State Farm                    State Farm
# 4277                    State Farm                    State Farm
# 4805  Schroeder Bros., Farms, Inc.  Schroeder Bros., Farms, Inc.
# 4806  Schroeder Bros., Farms, Inc.  Schroeder Bros., Farms, Inc.
# 4837                    State Farm                    State Farm
# 4840                         Droge                    State Farm
# 4841                         Droge                    State Farm
# 4844                    State Farm                    State Farm
# 5316                    State Farm                    State Farm
# 5318                    State Farm                    State Farm
# 5534                    Wirz, Inc.                    Wirz, Inc.
# 5707                    State Farm                    State Farm
# 5708                    State Farm                    State Farm
# 5712                    State Farm                    State Farm
# 5714                    State Farm                    State Farm
# 5758                    State Farm                    State Farm
# 5759                    State Farm                    State Farm
# 5761                    State Farm                    State Farm
# 5770                    State Farm                    State Farm
# 5772                    State Farm                    State Farm
# 5780                    State Farm                    State Farm
# 5781                    State Farm                    State Farm
# 5783                    State Farm                    State Farm
# 5784                    State Farm                    State Farm
# 6286                    State Farm                    State Farm
# 6289                    State Farm                    State Farm
# 6302                    State Farm                    State Farm
# 6303                    State Farm                    State Farm
# 6304                    State Farm                    State Farm
# 6306                    State Farm                    State Farm
# 6906                    State Farm                    State Farm
#
#                  S_G      winter_S_G  S_YR  winter_S_YR S_GCODE  \
# 127       Uihlein Fm      Uihlein Fm  2000       2002.0    ny01
# 405       State Farm      State Farm  2010       2009.0       0
# 407       State Farm      State Farm  2011       2008.0       0
# 489       State Farm      State Farm  2011       2010.0       0
# 490       State Farm      State Farm  2011       2010.0       0
# 514       State Farm      State Farm  2011       2010.0       0
# 515       State Farm      State Farm  2011       2010.0       0
# 2206      State Farm      State Farm  2009       2010.0       0
# 2212      State Farm      State Farm  2010       2009.0       0
# 2214      State Farm      State Farm  2011       2008.0       0
# 2217      State Farm      State Farm  2011       2009.0       0
# 2219      State Farm      State Farm  2011       2009.0       0
# 2945      State Farm      State Farm  2011       2009.0       0
# 2971      State Farm      State Farm  2011       2010.0       0
# 2972      State Farm      State Farm  2011       2010.0       0
# 2973      State Farm      State Farm  2011       2010.0       0
# 2974      State Farm      State Farm  2011       2010.0       0
# 2976      State Farm      State Farm  2011       2010.0       0
# 2977      State Farm      State Farm  2011       2010.0       0
# 2978      State Farm      State Farm  2011       2010.0       0
# 3272      State Farm      State Farm  2011       2010.0       0
# 3274      State Farm      State Farm  2011       2010.0       0
# 3275      State Farm      State Farm  2011       2010.0       0
# 3276      State Farm      State Farm  2011       2010.0       0
# 3280      State Farm      State Farm  2011       2010.0       0
# 3608      State Farm      State Farm  2009       2010.0       0
# 3609      State Farm      State Farm  2011       2010.0       0
# 3610      State Farm      State Farm  2011       2010.0       0
# 3612      State Farm      State Farm  2011       2010.0       0
# 4276      State Farm      State Farm  2010       2009.0       0
# 4277      State Farm      State Farm  2011       2008.0       0
# 4805  Schroeder Bros  Schroeder Bros  2009       2008.0     216
# 4806  Schroeder Bros  Schroeder Bros  2009       2008.0     216
# 4837      State Farm      State Farm  2010       2009.0       0
# 4840           Droge      State Farm  2011       2009.0    mt05
# 4841           Droge      State Farm  2011       2009.0    mt05
# 4844      State Farm      State Farm  2011       2008.0       0
# 5316      State Farm      State Farm  2011       2009.0       0
# 5318      State Farm      State Farm  2011       2009.0       0
# 5534            Wirz            Wirz  2003       2002.0     236
# 5707      State Farm      State Farm  2010       2009.0       0
# 5708      State Farm      State Farm  2010       2009.0       0
# 5712      State Farm      State Farm  2011       2008.0       0
# 5714      State Farm      State Farm  2011       2009.0       0
# 5758      State Farm      State Farm  2009       2010.0       0
# 5759      State Farm      State Farm  2009       2010.0       0
# 5761      State Farm      State Farm  2009       2010.0       0
# 5770      State Farm      State Farm  2009       2010.0       0
# 5772      State Farm      State Farm  2009       2010.0       0
# 5780      State Farm      State Farm  2011       2010.0       0
# 5781      State Farm      State Farm  2011       2010.0       0
# 5783      State Farm      State Farm  2011       2010.0       0
# 5784      State Farm      State Farm  2011       2010.0       0
# 6286      State Farm      State Farm  2010       2009.0       0
# 6289      State Farm      State Farm  2011       2008.0       0
# 6302      State Farm      State Farm  2011       2010.0       0
# 6303      State Farm      State Farm  2011       2010.0       0
# 6304      State Farm      State Farm  2011       2010.0       0
# 6306      State Farm      State Farm  2011       2010.0       0
# 6906      State Farm      State Farm  2011       2010.0       0
#
#      winter_S_GCODE S_STATE winter_S_STATE
# 127            ny01      NY             NY
# 405               0      WI             WI
# 407               0      WI             WI
# 489               0      WI             WI
# 490               0      WI             WI
# 514               0      WI             WI
# 515               0      WI             WI
# 2206              0      WI             WI
# 2212              0      WI             WI
# 2214              0      WI             WI
# 2217              0      WI             WI
# 2219              0      WI             WI
# 2945              0      WI             WI
# 2971              0      WI             WI
# 2972              0      WI             WI
# 2973              0      WI             WI
# 2974              0      WI             WI
# 2976              0      WI             WI
# 2977              0      WI             WI
# 2978              0      WI             WI
# 3272              0      WI             WI
# 3274              0      WI             WI
# 3275              0      WI             WI
# 3276              0      WI             WI
# 3280              0      WI             WI
# 3608              0      WI             WI
# 3609              0      WI             WI
# 3610              0      WI             WI
# 3612              0      WI             WI
# 4276              0      WI             WI
# 4277              0      WI             WI
# 4805            216      WI             WI
# 4806            216      WI             WI
# 4837              0      WI             WI
# 4840           mt05      MT             WI
# 4841           mt05      MT             WI
# 4844              0      WI             WI
# 5316              0      WI             WI
# 5318              0      WI             WI
# 5534            236      WI             WI
# 5707              0      WI             WI
# 5708              0      WI             WI
# 5712              0      WI             WI
# 5714              0      WI             WI
# 5758              0      WI             WI
# 5759              0      WI             WI
# 5761              0      WI             WI
# 5770              0      WI             WI
# 5772              0      WI             WI
# 5780              0      WI             WI
# 5781              0      WI             WI
# 5783              0      WI             WI
# 5784              0      WI             WI
# 6286              0      WI             WI
# 6289              0      WI             WI
# 6302              0      WI             WI
# 6303              0      WI             WI
# 6304              0      WI             WI
# 6306              0      WI             WI
# 6906              0      WI             WI

# %%
df.loc[df["winter_S_STATE"] == "PE", combined_columns]
# Out:
#       CERT_N  winter_CERT_N      SNAME winter_SNAME GCODE  winter_GCODE  \
# 42    115254       115254.0    Bula Po      Bula Po   114         114.0
# 92    105291       105291.0    Bula Po      Bula Po   114         114.0
# 93    105297       105297.0    Bula Po      Bula Po   114         114.0
# 94    104021       104021.0    Bula Po      Bula Po   114         114.0
# 1034  112195       112195.0  Schroeder    Schroeder   216         216.0
# 1792  105290       105290.0    Bula Po      Bula Po   114         114.0
# 1793  105298       105298.0    Bula Po      Bula Po   114         114.0
# 1794  107123       107123.0    Bula Po      Bula Po   114         114.0
# 1795  107123       107123.0    Bula Po      Bula Po   114         114.0
# 1796  109225       109225.0    Bula Po      Bula Po   114         114.0
# 1797  109242       109242.0    Bula Po      Bula Po   114         114.0
# 1798  109242       109242.0    Bula Po      Bula Po   114         114.0
# 1799  109252       109252.0    Bula Po      Bula Po   114         114.0
# 1800  104022       104022.0    Bula Po      Bula Po   114         114.0
# 1801  110319       110319.0    Bula Po      Bula Po   114         114.0
# 1802  106105       106105.0    Bula Po      Bula Po   114         114.0
# 1803  106106       106106.0    Bula Po      Bula Po   114         114.0
# 1804  106106       106106.0    Bula Po      Bula Po   114         114.0
# 1805  108274       108274.0    Bula Po      Bula Po   114         114.0
# 1806  108289       108289.0    Bula Po      Bula Po   114         114.0
# 4537  104020       104020.0    Bula Po      Bula Po   114         114.0
# 4538  105289       105289.0    Bula Po      Bula Po   114         114.0
# 4539  106109       106109.0    Bula Po      Bula Po   114         114.0
# 5484  112268       112268.0  Guen Farm    Guen Farm   149         149.0
# 5485  113137       113137.0  Guen Farm    Guen Farm   149         149.0
# 5486  114103       114103.0  Guen Farm    Guen Farm   149         149.0
# 6546  113072       113072.0    Bula Po      Bula Po   114         114.0
# 6547  114057       114057.0    Bula Po      Bula Po   114         114.0
#
#                  VARIETY      winter_VARIETY                   S_GRW  \
# 42               Actrice             Actrice      Phytocultures Ltd.
# 92                 Adora               Adora             PEI Produce
# 93                 Adora               Adora      Phytocultures Ltd.
# 94                 Adora               Adora             PEI Produce
# 1034  Dark Red Chieftain  Dark Red Chieftain  Martin Visser and Sons
# 1792              Fabula              Fabula      Phytocultures Ltd.
# 1793              Fabula              Fabula      Phytocultures Ltd.
# 1794              Fabula              Fabula      Phytocultures Ltd.
# 1795              Fabula              Fabula      Phytocultures Ltd.
# 1796              Fabula              Fabula      Phytocultures Ltd.
# 1797              Fabula              Fabula      Phytocultures Ltd.
# 1798              Fabula              Fabula      Phytocultures Ltd.
# 1799              Fabula              Fabula      Phytocultures Ltd.
# 1800              Fabula              Fabula      Phytocultures Ltd.
# 1801              Fabula              Fabula      Phytocultures Ltd.
# 1802              Fabula              Fabula      Phytocultures Ltd.
# 1803              Fabula              Fabula      Phytocultures Ltd.
# 1804              Fabula              Fabula      Phytocultures Ltd.
# 1805              Fabula              Fabula      Phytocultures Ltd.
# 1806              Fabula              Fabula      Phytocultures Ltd.
# 4537               Rodeo               Rodeo      Phytocultures Ltd.
# 4538               Rodeo               Rodeo      Phytocultures Ltd.
# 4539               Rodeo               Rodeo      Phytocultures Ltd.
# 5484            Snowbird            Snowbird      Phytocultures Ltd.
# 5485            Snowbird            Snowbird      Phytocultures Ltd.
# 5486            Snowbird            Snowbird      Phytocultures LTD.
# 6546             Sylvana             Sylvana      Phytocultures LTD.
# 6547             Sylvana             Sylvana      Phytocultures LTD.
#
#                 winter_S_GRW            S_G     winter_S_G  S_YR  winter_S_YR  \
# 42        Phytocultures Ltd.        Phytocu        Phytocu  2015       2015.0
# 92               PEI Produce    PEI Produce    PEI Produce  2004       2004.0
# 93        Phytocultures Ltd.        Phytocu        Phytocu  2005       2005.0
# 94               PEI Produce    PEI Produce    PEI Produce  2004       2004.0
# 1034  Martin Visser and Sons         Martin         Martin  2012       2012.0
# 1792      Phytocultures Ltd.        Phytocu        Phytocu  2004       2004.0
# 1793      Phytocultures Ltd.        Phytocu        Phytocu  2005       2005.0
# 1794      Phytocultures Ltd.        Phytocu        Phytocu  2005       2005.0
# 1795      Phytocultures Ltd.        Phytocu        Phytocu  2005       2005.0
# 1796      Phytocultures Ltd.        Phytocu        Phytocu  2008       2008.0
# 1797      Phytocultures Ltd.        Phytocu        Phytocu  2005       2005.0
# 1798      Phytocultures Ltd.        Phytocu        Phytocu  2005       2005.0
# 1799      Phytocultures Ltd.        Phytocu        Phytocu  2009       2009.0
# 1800      Phytocultures Ltd.        Phytocu        Phytocu  2004       2004.0
# 1801      Phytocultures Ltd.        Phytocu        Phytocu  2009       2009.0
# 1802      Phytocultures Ltd.        Phytocu        Phytocu  2005       2005.0
# 1803      Phytocultures Ltd.        Phytocu        Phytocu  2004       2004.0
# 1804      Phytocultures Ltd.        Phytocu        Phytocu  2004       2004.0
# 1805      Phytocultures Ltd.        Phytocu        Phytocu  2005       2005.0
# 1806      Phytocultures Ltd.        Phytocu        Phytocu  2008       2008.0
# 4537      Phytocultures Ltd.        Phytocu        Phytocu  2004       2004.0
# 4538      Phytocultures Ltd.        Phytocu        Phytocu  2004       2004.0
# 4539      Phytocultures Ltd.        Phytocu        Phytocu  2004       2004.0
# 5484      Phytocultures Ltd.        Phytocu        Phytocu  2012       2012.0
# 5485      Phytocultures Ltd.        Phytocu        Phytocu  2012       2012.0
# 5486      Phytocultures LTD.  Phytocultures  Phytocultures  2012       2012.0
# 6546      Phytocultures LTD.        Phytocu  Phytocultures  2013       2013.0
# 6547      Phytocultures LTD.  Phytocultures  Phytocultures  2013       2013.0
#
#      S_GCODE winter_S_GCODE S_STATE winter_S_STATE
# 42     pei05          pei05      PE             PE
# 92      pei2           pei2      PE             PE
# 93     pei05          pei05      PE             PE
# 94      pei2           pei2      PE             PE
# 1034   pei10          pei10      PE             PE
# 1792   pei05          pei05      PE             PE
# 1793   pei05          pei05      PE             PE
# 1794   pei05          pei05      PE             PE
# 1795   pei05          pei05      PE             PE
# 1796   pei05          pei05      PE             PE
# 1797   pei05          pei05      PE             PE
# 1798   pei05          pei05      PE             PE
# 1799   pei05          pei05      PE             PE
# 1800   pei05          pei05      PE             PE
# 1801   pei05          pei05      PE             PE
# 1802   pei05          pei05      PE             PE
# 1803   pei05          pei05      PE             PE
# 1804   pei05          pei05      PE             PE
# 1805   pei05          pei05      PE             PE
# 1806   pei05          pei05      PE             PE
# 4537   pei05          pei05      PE             PE
# 4538   pei05          pei05      PE             PE
# 4539   pei05          pei05      PE             PE
# 5484   pei05          pei05      PE             PE
# 5485   pei05          pei05      PE             PE
# 5486   pei05          pei05      PE             PE
# 6546   pei05          pei05      PE             PE
# 6547   pei05          pei05      PE             PE

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# #### Virus after each inspection

# %%
SR1 = df.columns[df.columns.str.contains("SR1")].tolist()
SR2 = df.columns[df.columns.str.contains("SR2")].tolist()

SR1, SR2
# Out:
# (['SR1_LR', 'SR1_MOS', 'SR1_ST', 'SR1_TOTV', 'SR1_MIX'],
#  ['SR2_LR', 'SR2_MOS', 'SR2_ST', 'SR2_TOTV', 'SR2_BRR', 'SR2_MIX'])

# %%
df.loc[:, (df.columns.str.contains("SR2")) | (df.columns.str.contains("SR1")) ]
# Out:
#       SR1_LR  SR1_MOS  SR1_ST  SR1_TOTV  SR1_MIX  SR2_LR  SR2_MOS  SR2_ST  \
# 0        0.0     0.00     0.0      0.00  0.00000     0.0     0.00     0.0
# 1        0.0     0.00     0.0      0.00  0.20202     0.0     0.00     0.0
# 2        0.0     0.44     0.0      0.44  0.00000     0.0     0.44     0.0
# 3        0.0     0.00     0.0      0.00  0.00000     0.0     0.00     0.0
# 4        0.0     0.00     0.0      0.00  0.00000     0.0     0.00     0.0
# ...      ...      ...     ...       ...      ...     ...      ...     ...
# 7497     0.0     0.00     0.0      0.00  0.00000     0.0     0.00     0.0
# 7498     0.0     0.00     0.0      0.00  0.00000     0.0     0.00     0.0
# 7499     0.0     0.00     0.0      0.00  0.00000     0.0     0.00     0.0
# 7500     0.0     0.00     0.0      0.00  0.00000     0.0     0.00     0.0
# 7501     0.0     0.00     0.0      0.00  0.00000     0.0     0.00     0.0
#
#       SR2_TOTV  SR2_BRR  SR2_MIX
# 0         0.00      0.0  0.00000
# 1         0.00      0.0  0.00000
# 2         0.44      0.0  0.03788
# 3         0.00      0.0  0.00000
# 4         0.00      0.0  0.00000
# ...        ...      ...      ...
# 7497      0.00      0.0  0.00000
# 7498      0.00      0.0  0.00000
# 7499      0.00      0.0  0.00000
# 7500      0.00      0.0  0.00000
# 7501      0.00      0.0  0.00000
#
# [7502 rows x 11 columns]

# %% [markdown]
# #### Relationship between source and virus

# %% [markdown]
# Group by categories:
#
# - S_GRW
# - S_YR
# - S_STATE
# - Variety

# %% [markdown]
# Virus Type
# - LR (Leaf Roll Virus)
# - MOS (Mosaic Virus)
# - ST (Spindle Tuber viroid)
# - MIX (Foreign Variety)

# %% [markdown]
# Disease type

# %%
df.columns[df.columns.str.contains("ST")]
# Out:
# Index(['S_STATE', 'START_PLTG', 'DATE_1ST', 'NO_LR_1ST', 'NO_MOS_1ST',
#        'NO_ST_1ST', 'SR1_ST', 'NO_MIX_1ST', 'AC_MIX_1ST', 'SR2_ST', 'SRF_ST',
#        'ASTRYELOS', 'STAND', 'PSTV_F', 'LAST_MOD', 'LAST_TIM', 'STOP', 'STATE',
#        'winter_S_STATE', 'winter_PSTV'],
#       dtype='object')

# %%
# LR = ['SR1_LR', 'SR2_LR', 'winter_LR']
# MOS = ['SR1_MOS', 'SR2_MOS', 'winter_MOS']

# %%
import re
word = 'SR_LR'
regexp = re.compile(r'[SR1|SR2|winter]_LR$')
if regexp.search(word):
      print (word)
# Out:
# SR_LR

# %%
def find_virus_columns(virus):
    return [x for x in df.columns.tolist() if re.compile(r'[SR1|SR2|winter]_P*{virus}V*$'.format(virus = virus)).search(x)]
    
find_virus_columns("LR")
# Out:
# ['SR1_LR', 'SR2_LR', 'winter_LR']

# %%
find_virus_columns("MOS")
# Out:
# ['SR1_MOS', 'SR2_MOS', 'winter_MOS']

# %%
find_virus_columns("ST")
# Out:
# ['SR1_ST', 'SR2_ST', 'winter_PSTV']

# %%
find_virus_columns("MIX")
# Out:
# ['SR1_MIX', 'SR2_MIX', 'winter_MIX']

# %%
a = list(np.sort(df["S_YR"].unique()))
a.append("all")
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-e4bc6a27e47d> in <module>
# ----> 1 a = list(np.sort(df["S_YR"].unique()))
#       2 a.append("all")
#       3 a
#
# NameError: name 'np' is not defined

# %%
virus_columns = find_virus_columns("LR")
frequent_state = df["S_STATE"].value_counts()[:8].index.to_list()
temp = df[df["S_STATE"].isin(frequent_state)].groupby("S_STATE").mean()[virus_columns]

# %%
    
def plot_virus_by_state(state_number, virus, year = "all"):
    virus_columns = find_virus_columns(virus)
    if year == "all":
        temp = df  
    else:  
        temp = df[df["S_YR"] == year]
    frequent_state = temp["S_STATE"].value_counts()[:state_number].index.to_list()
    temp = temp[temp["S_STATE"].isin(frequent_state)].groupby("S_STATE").mean()[virus_columns]
    fig = go.Figure()
    fig.add_trace(go.Bar(x=temp.index,
                    y = temp.iloc[:,0],
                    text=np.round(temp.iloc[:,0],3),
                    textposition='outside',
                    name=temp.columns[0],
                    marker_color='rgb(55, 83, 109)'
                    ))
    fig.add_trace(go.Bar(x=temp.index,
                    y = temp.iloc[:,1],
                    text=np.round(temp.iloc[:,1],3),
                    textposition='outside',
                    name= temp.columns[1],
                    marker_color='rgb(26, 118, 255)'
                    ))

    fig.add_trace(go.Bar(x=temp.index,
                    y = temp.iloc[:,2],
                    text=np.round(temp.iloc[:,2],3),
                    textposition='outside',
                    name=temp.columns[2],
                    marker_color='crimson'
                    ))

    fig.update_layout(
        title='US Export of Plastic Scrap',
        xaxis_tickfont_size=14,
        yaxis=dict(
            title='USD (millions)',
            titlefont_size=16,
            tickfont_size=14,
        ),
        legend=dict(
            x=0,
            y=1.0,
            bgcolor='rgba(255, 255, 255, 0)',
            bordercolor='rgba(255, 255, 255, 0)'
        ),
        barmode='group',
        bargap=0.15, # gap between bars of adjacent location coordinates.
        bargroupgap=0.1 # gap between bars of the same location coordinate.
    )
    fig.show()

# %%
plot_virus_by_state(10, "LR", "all")

# %%
def plot_virus_inspection(virus):
    fig, ax = plt.subplots(figsize = (10,6))
    virus_columns = find_virus_columns(virus)
    df[df["S_STATE"].isin(frequent_state)].groupby("S_STATE").mean()[virus_columns].plot(kind = "barh", ax = ax)
    ax.tick_params(axis='x', rotation=0)
    ax.set_title("Virus across state")
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    plt.tight_layout()


plot_virus_inspection("MOS")

# %%
frequent_state = df["S_STATE"].value_counts()[:8].index.to_list()
frequent_state

# %%
df.columns[df.columns.str.contains("SR1")]

# %%
target_virus = ['SR1_ST','SR1_MIX',"SR1_LR"]

# %%
fig, ax = plt.subplots(figsize = (10,6))
df[df["S_STATE"].isin(frequent_state)].groupby("S_STATE").mean()[target_virus].plot(kind = "barh", ax = ax)
ax.tick_params(axis='x', rotation=0)
ax.set_title("Virus across state")
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()

plt.savefig("Virus_across_state")

# %%
frequent_variety = df["VARIETY"].value_counts()[:15].index.tolist()
frequent_variety

# %%
def plot_virus_by_variety(variety_number, virus, year = "all"):
    virus_columns = find_virus_columns(virus)
    if year == "all":
        temp = df  
    else:  
        temp = df[df["S_YR"] == year]
    
   
    
    frequent_variety = temp["VARIETY"].value_counts()[:variety_number].index.tolist()
    temp = temp[temp["VARIETY"].isin(frequent_variety)].groupby("VARIETY").mean()[virus_columns]
    fig = go.Figure()
    fig.add_trace(go.Bar(y=temp.index,
                    x = temp.iloc[:,0],
                    text=np.round(temp.iloc[:,0],3),
                    textposition='outside',
                    name=temp.columns[0],
                    marker_color='rgb(55, 83, 109)',
                    orientation='h'
                    ))
    fig.add_trace(go.Bar(y=temp.index,
                    x = temp.iloc[:,1],
                    text=np.round(temp.iloc[:,1],3),
                    textposition='outside',
                    name= temp.columns[1],
                    marker_color='rgb(26, 118, 255)',
                    orientation='h'
                    ))

    fig.add_trace(go.Bar(y=temp.index,
                    x = temp.iloc[:,2],
                    text=np.round(temp.iloc[:,2],3),
                    textposition='outside',
                    name=temp.columns[2],
                    marker_color='crimson',
                    orientation='h'
                    ))

    fig.update_layout(
        title='US Export of Plastic Scrap',
        xaxis_tickfont_size=14,
        yaxis=dict(
            title='USD (millions)',
            titlefont_size=16,
            tickfont_size=14,
        ),
        legend=dict(
            y=0,
            x=1.0,
            bgcolor='rgba(255, 255, 255, 0)',
            bordercolor='rgba(255, 255, 255, 0)'
        ),
        barmode='group',
        bargap=0.15, # gap between bars of adjacent location coordinates.
        bargroupgap=0.1 # gap between bars of the same location coordinate.
    )
    fig.show()

# %%
virus_columns = find_virus_columns("LR")
# if year == "all":
#     temp = df  
# else:  
#     temp = df[df["S_YR"] == year]


temp = df
frequent_variety = temp["VARIETY"].value_counts()[:15].index.tolist()
temp = temp[temp["VARIETY"].isin(frequent_variety)].groupby("VARIETY").mean()[virus_columns]
temp

# %%
plot_virus_by_variety(10, "LR", "all")

# %%
df["S_G"]

# %%
def plot_virus_by_variety(variety_number, virus, year = "all"):
    virus_columns = find_virus_columns(virus)
    if year == "all":
        temp = df  
    else:  
        temp = df[df["S_YR"] == year]
    
   
    
    frequent_variety = temp["S_G"].value_counts()[:variety_number].index.tolist()
    temp = temp[temp["S_G"].isin(frequent_variety)].groupby("S_G").mean()[virus_columns]
    fig = go.Figure()
    fig.add_trace(go.Bar(y=temp.index,
                    x = temp.iloc[:,0],
                    text=np.round(temp.iloc[:,0],3),
                    textposition='outside',
                    name=temp.columns[0],
                    marker_color='rgb(55, 83, 109)',
                    orientation='h'
                    ))
    fig.add_trace(go.Bar(y=temp.index,
                    x = temp.iloc[:,1],
                    text=np.round(temp.iloc[:,1],3),
                    textposition='outside',
                    name= temp.columns[1],
                    marker_color='rgb(26, 118, 255)',
                    orientation='h'
                    ))

    fig.add_trace(go.Bar(y=temp.index,
                    x = temp.iloc[:,2],
                    text=np.round(temp.iloc[:,2],3),
                    textposition='outside',
                    name=temp.columns[2],
                    marker_color='crimson',
                    orientation='h'
                    ))

    fig.update_layout(
        title='US Export of Plastic Scrap',
        xaxis_tickfont_size=14,
        yaxis=dict(
            title='USD (millions)',
            titlefont_size=16,
            tickfont_size=14,
        ),
        legend=dict(
            y=0,
            x=1.0,
            bgcolor='rgba(255, 255, 255, 0)',
            bordercolor='rgba(255, 255, 255, 0)'
        ),
        barmode='group',
        bargap=0.15, # gap between bars of adjacent location coordinates.
        bargroupgap=0.1 # gap between bars of the same location coordinate.
    )
    fig.show()

# %%
# fig, ax = plt.subplots(figsize = (10,6))
# df[df["VARIETY"].isin(frequent_variety)].groupby("VARIETY").mean()[find_virus_columns("LR")].plot(kind = "barh", ax = ax)
# ax.tick_params(axis='x', rotation=0)
# ax.tick_params(axis="y", rotation = 0)
# ax.set_title("Virus across potato variety")
# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)
# plt.tight_layout()
# plt.savefig("Virus_across_potato_variety")
